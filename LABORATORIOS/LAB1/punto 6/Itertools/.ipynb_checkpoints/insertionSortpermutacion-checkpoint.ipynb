# %%
"""
@author: Jhon Jairo
"""
import math
import random
import itertools
from itertools import permutations
from math import factorial

#tomado de notebooK corrección y analisis de algoritmos
def insertion_sort(A):
    j = 1
    while j < len(A):
        key = A[j]
        i = j - 1
        while (i >= 0) and (A[i] > key):
            A[i + 1] = A[i]
            i = i -1
        A[i + 1] = key
        j = j + 1
    return A

#basado en el codigo de insertionsortPermutacion.py
def randomPerm(n):
    v=[]
    for i in range(n):
        v.append(i+1)
    for i in range(len(v)-1):
        j = random.randint(i, len(v)-1)
        aux = v[i]
        v[i] = v[j]
        v[j] = aux
    return v

def isortSteps(a):
    v = []
    for i in range(len(a)):
        v.append(a[i])
        
    steps = 0
    for i in range(1,len(v)):
        x = v[i]
        j = i-1
        while (j > -1) and (v[j] > x):
            v[j+1] = v[j]
            j = j -1
            steps = steps + 3
        steps = steps + 1
        v[j+1] = x
        steps = steps + 4
    steps = steps + 1
    #print(a)
    return steps

#print(randomPerm(5))

print("---------------------------------------------------")
print("Programa en Python que ejecuta Insertion Sort sobre")
print("todas las permutaciones                            ")
print("Version usando: permutations de Itertools          ")
print("---------------------------------------------------")
print("Arreglo B: ", "\n")
B = [5, 4, 3, 2, 1]
print(B, "\n")
#insertion_sort(B)
#print (B, "\n")
print("Insertion sort sobre todas las permutaciones de un arreglo B \n")
print("tamaño de B: ", len(B), "\n")
print()

miLista=list(itertools.permutations(B, len(B)))

#print(type(miLista))
#tmp = list(miLista[0])
#print(type(tmp))

for i in range(len(miLista)):
    print(" permutacion ", i+1, miLista[i])
    print("lista ordenada ", insertion_sort(list(miLista[i])), "\n")
# Out:
# ---------------------------------------------------
# Programa en Python que ejecuta Insertion Sort sobre
# todas las permutaciones
# Version usando: permutations de Itertools
# ---------------------------------------------------
# Arreglo B:
#
# [5, 4, 3, 2, 1]
#
# Insertion sort sobre todas las permutaciones de un arreglo B
#
# tamaño de B:  5
#
#
#  permutacion  1 (5, 4, 3, 2, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  2 (5, 4, 3, 1, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  3 (5, 4, 2, 3, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  4 (5, 4, 2, 1, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  5 (5, 4, 1, 3, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  6 (5, 4, 1, 2, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  7 (5, 3, 4, 2, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  8 (5, 3, 4, 1, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  9 (5, 3, 2, 4, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  10 (5, 3, 2, 1, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  11 (5, 3, 1, 4, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  12 (5, 3, 1, 2, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  13 (5, 2, 4, 3, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  14 (5, 2, 4, 1, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  15 (5, 2, 3, 4, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  16 (5, 2, 3, 1, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  17 (5, 2, 1, 4, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  18 (5, 2, 1, 3, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  19 (5, 1, 4, 3, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  20 (5, 1, 4, 2, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  21 (5, 1, 3, 4, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  22 (5, 1, 3, 2, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  23 (5, 1, 2, 4, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  24 (5, 1, 2, 3, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  25 (4, 5, 3, 2, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  26 (4, 5, 3, 1, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  27 (4, 5, 2, 3, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  28 (4, 5, 2, 1, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  29 (4, 5, 1, 3, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  30 (4, 5, 1, 2, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  31 (4, 3, 5, 2, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  32 (4, 3, 5, 1, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  33 (4, 3, 2, 5, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  34 (4, 3, 2, 1, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  35 (4, 3, 1, 5, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  36 (4, 3, 1, 2, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  37 (4, 2, 5, 3, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  38 (4, 2, 5, 1, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  39 (4, 2, 3, 5, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  40 (4, 2, 3, 1, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  41 (4, 2, 1, 5, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  42 (4, 2, 1, 3, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  43 (4, 1, 5, 3, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  44 (4, 1, 5, 2, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  45 (4, 1, 3, 5, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  46 (4, 1, 3, 2, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  47 (4, 1, 2, 5, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  48 (4, 1, 2, 3, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  49 (3, 5, 4, 2, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  50 (3, 5, 4, 1, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  51 (3, 5, 2, 4, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  52 (3, 5, 2, 1, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  53 (3, 5, 1, 4, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  54 (3, 5, 1, 2, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  55 (3, 4, 5, 2, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  56 (3, 4, 5, 1, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  57 (3, 4, 2, 5, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  58 (3, 4, 2, 1, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  59 (3, 4, 1, 5, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  60 (3, 4, 1, 2, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  61 (3, 2, 5, 4, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  62 (3, 2, 5, 1, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  63 (3, 2, 4, 5, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  64 (3, 2, 4, 1, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  65 (3, 2, 1, 5, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  66 (3, 2, 1, 4, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  67 (3, 1, 5, 4, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  68 (3, 1, 5, 2, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  69 (3, 1, 4, 5, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  70 (3, 1, 4, 2, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  71 (3, 1, 2, 5, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  72 (3, 1, 2, 4, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  73 (2, 5, 4, 3, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  74 (2, 5, 4, 1, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  75 (2, 5, 3, 4, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  76 (2, 5, 3, 1, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  77 (2, 5, 1, 4, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  78 (2, 5, 1, 3, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  79 (2, 4, 5, 3, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  80 (2, 4, 5, 1, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  81 (2, 4, 3, 5, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  82 (2, 4, 3, 1, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  83 (2, 4, 1, 5, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  84 (2, 4, 1, 3, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  85 (2, 3, 5, 4, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  86 (2, 3, 5, 1, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  87 (2, 3, 4, 5, 1)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  88 (2, 3, 4, 1, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  89 (2, 3, 1, 5, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  90 (2, 3, 1, 4, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  91 (2, 1, 5, 4, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  92 (2, 1, 5, 3, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  93 (2, 1, 4, 5, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  94 (2, 1, 4, 3, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  95 (2, 1, 3, 5, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  96 (2, 1, 3, 4, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  97 (1, 5, 4, 3, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  98 (1, 5, 4, 2, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  99 (1, 5, 3, 4, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  100 (1, 5, 3, 2, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  101 (1, 5, 2, 4, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  102 (1, 5, 2, 3, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  103 (1, 4, 5, 3, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  104 (1, 4, 5, 2, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  105 (1, 4, 3, 5, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  106 (1, 4, 3, 2, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  107 (1, 4, 2, 5, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  108 (1, 4, 2, 3, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  109 (1, 3, 5, 4, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  110 (1, 3, 5, 2, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  111 (1, 3, 4, 5, 2)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  112 (1, 3, 4, 2, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  113 (1, 3, 2, 5, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  114 (1, 3, 2, 4, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  115 (1, 2, 5, 4, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  116 (1, 2, 5, 3, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  117 (1, 2, 4, 5, 3)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  118 (1, 2, 4, 3, 5)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  119 (1, 2, 3, 5, 4)
# lista ordenada  [1, 2, 3, 4, 5]
#
#  permutacion  120 (1, 2, 3, 4, 5)
# lista ordenada  [1, 2, 3, 4, 5]

# %%
print("-----------------------------------------------------------")    
print("hasta que valor se pueden generar las permutaciones        ")
print("-----------------------------------------------------------")
print("Arreglo B: \n")
print(B, "\n")
print("El numero de permutaciones que se pueden obtener para un   ")
print("conjunto de cardinalidad n es n! \n")
if len(miLista)==factorial(len(B)):
    print("# n de permutaciones de B  igual n!")
else:
    print("false")
# Out:
# -----------------------------------------------------------
# hasta que valor se pueden generar las permutaciones
# -----------------------------------------------------------
# Arreglo B:
#
# [5, 4, 3, 2, 1]
#
# El numero de permutaciones que se pueden obtener para un
# conjunto de cardinalidad n es n!
#
# # n de permutaciones de B  igual n!

# %%
print("-----------------------------------------------------------")    
print("Insertion Sort sobre una muestra aleatoria de permutaciones")
print("-----------------------------------------------------------")
print("Arreglo B: \n")
print(B, "\n")
print("muestras aleatorias de permutaciones del arreglo B: \n")

n=len(B)
sum = 0
min = n**3
max = 0
for i in range(len(B)):
    A = randomPerm(len(B))
    print("(", i+1 ,")","permutacion aleatoria: ", A )
    #print("arreglo B ordenado: ", insertion_sort(A))
    t = isortSteps(A)
    print ("# pasos :", t)
    print("arreglo B ordenado: ", insertion_sort(A), "\n")
   
    if t < min :
       min = t
    if t > max :
       max = t
    sum = sum + t

print ('Theoretical best time, ' + str(5*n - 4)) 
print ('Theoretical worst time,' + str((3.0/2.0)*n**2 + (7.0/2.0)*n - 4))
print ('Theoretical average time,' + str((3.0/4.0)*n**2 + (17.0/4.0)*n - 4))
print ('Experimenal best time, ' + str(min))
print ('Experimenal worst time,' + str(max))
print ('Experimenal average time,' + str(sum/n))
# Out:
# -----------------------------------------------------------
# Insertion Sort sobre una muestra aleatoria de permutaciones
# -----------------------------------------------------------
# Arreglo B:
#
# [5, 4, 3, 2, 1]
#
# muestras aleatorias de permutaciones del arreglo B:
#
# ( 1 ) permutacion aleatoria:  [5, 2, 3, 1, 4]
# # pasos : 39
# arreglo B ordenado:  [1, 2, 3, 4, 5]
#
# ( 2 ) permutacion aleatoria:  [2, 5, 1, 4, 3]
# # pasos : 36
# arreglo B ordenado:  [1, 2, 3, 4, 5]
#
# ( 3 ) permutacion aleatoria:  [5, 2, 1, 4, 3]
# # pasos : 39
# arreglo B ordenado:  [1, 2, 3, 4, 5]
#
# ( 4 ) permutacion aleatoria:  [5, 4, 3, 2, 1]
# # pasos : 51
# arreglo B ordenado:  [1, 2, 3, 4, 5]
#
# ( 5 ) permutacion aleatoria:  [2, 4, 5, 1, 3]
# # pasos : 36
# arreglo B ordenado:  [1, 2, 3, 4, 5]
#
# Theoretical best time, 21
# Theoretical worst time,51.0
# Theoretical average time,36.0
# Experimenal best time, 36
# Experimenal worst time,51
# Experimenal average time,40.2
